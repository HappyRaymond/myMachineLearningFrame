# %%
from Frame import ensemble_Bayesian # 导入库
from sklearn import datasets     # 波士頓房價數據集
import os
import pandas as pd
from sklearn import preprocessing
import numpy as np

# %%
from sklearn import datasets  # 导入库
from sklearn.model_selection import train_test_split

boston = datasets.load_boston()  # 导入波士顿房价数据

train = boston.data  # sample
target = boston.target  # target
# 切割数据样本集合测试集
X_train, X_test, y_train, y_test = train_test_split(train, target, test_size=0.2)  # 20%测试集；80%训练集

# %%
bo = ensemble_Bayesian.myBayesianoptimazation("catboost",X_train, X_test, y_train, y_test,random_seed = 1998,save_path = "./ensembleLearning_hk/catboost/",kFold = 1 )
bo.run()

# %%
bo = ensemble_Bayesian.myBayesianoptimazation("xgboost",X_train, X_test, y_train, y_test,random_seed = 1998,save_path = "./ensembleLearning_hk/xgboost/",kFold = 10 )
bo.run()
# Out:
# |   iter    |  target   |    eta    | max_depth | reg_alpha | reg_la... | subsample |
# -------------------------------------------------------------------------------------
# [15:11:46] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:11:47] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:11:47] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:11:47] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
bo = ensemble_Bayesian.myBayesianoptimazation("lightgbm",X_train, X_test, y_train, y_test,random_seed = 1998,save_path = "./ensembleLearning_hk/lightgbm/",kFold = 10 )
bo.run()
# Out:
# |   iter    |  target   | boosti... | colsam... | learni... | n_esti... | reg_alpha | reg_la... | subsample | subsam... |
# -------------------------------------------------------------------------------------------------------------------------
# |  1        |  0.6683   |  2.985    |  0.5876   |  0.5965   |  1.52e+03 |  0.6149   |  1.09     |  0.761    |  1.423    |
# |  2        | -0.2826   |  2.079    |  0.8242   |  0.9311   |  1.114e+0 |  0.00785  |  1.945    |  0.7242   |  2.272    |
# |  3        |  0.8385   |  2.226    |  0.7663   |  0.06763  |  222.7    |  0.5563   |  1.317    |  0.9637   |  2.799    |
# |  4        |  0.5944   |  2.08     |  0.5177   |  0.792    |  1.249e+0 |  1.475    |  0.2731   |  0.5323   |  3.946    |
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ...

# %%
bo = ensemble_Bayesian.myBayesianoptimazation("Adaboost",X_train, X_test, y_train, y_test,random_seed = 1998,save_path = "./ensembleLearning_hk/Adaboost/",kFold = 10 )
bo.run()
# Out:
# |   iter    |  target   | criterion | learni... |   loss    | n_esti... | splitter  |
# -------------------------------------------------------------------------------------
# |  1        |  0.8437   |  0.0185   |  0.1536   |  2.16     |  262.1    |  1.878    |
# |  2        |  0.8695   |  0.8943   |  0.4909   |  2.677    |  505.5    |  1.576    |
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\LYL\lib\site-packages\bayes_opt\target_space.py in probe(self, params)
#     190         try:
# --> 191             target = self._cache[_hashable(x)]
#     192         except KeyError:
#
# KeyError: (0.433397558828865, 0.6680220920069215, 0.007465681747629627, 1672.9489748890278, 1.3281267294346482)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ...

# %%
vbo = ensemble_Bayesian.myBayesianoptimazation("SVR",X_train, X_test, y_train, y_test,random_seed = 1998,save_path = "./ensembleLearning_hk/SVR/",kFold = 10 )
bo.run()
# Out:
# |   iter    |  target   | criterion | learni... |   loss    | n_esti... | splitter  |
# -------------------------------------------------------------------------------------
# |  1        |  0.8674   |  1.69     |  0.347    |  2.803    |  1.18e+03 |  0.01783  |
# |  2        |  0.8692   |  0.5515   |  0.4201   |  0.231    |  1.599e+0 |  0.8368   |
# |  3        |  0.872    |  0.7368   |  0.9616   |  0.4837   |  1.027e+0 |  0.4661   |
# |  4        |  0.8683   |  0.09472  |  0.8427   |  2.161    |  1.244e+0 |  0.06096  |
# |  5        |  0.8654   |  0.57     |  0.2532   |  0.2466   |  226.7    |  0.09427  |
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\LYL\lib\site-packages\bayes_opt\target_space.py in probe(self, params)
#     190         try:
# --> 191             target = self._cache[_hashable(x)]
#     192         except KeyError:
#
# ...

# %%
bo = ensemble_Bayesian.myBayesianoptimazation("RandomForest",X_train, X_test, y_train, y_test,random_seed = 1998,save_path = "./ensembleLearning_hk/RandomForest/",kFold = 10 )
bo.run()
# Out:
# |   iter    |  target   | min_sa... | min_sa... | n_esti... | oob_score |
# -------------------------------------------------------------------------
# |  1        |  0.8692   |  2.412    |  2.706    |  275.0    |  0.5881   |
# |  2        |  0.8725   |  2.753    |  3.133    |  785.7    |  0.7879   |
# |  3        |  0.8576   |  3.265    |  3.379    |  220.4    |  1.325    |
# |  4        |  0.8726   |  2.728    |  2.41     |  926.5    |  0.2483   |
# |  5        |  0.8716   |  2.489    |  3.663    |  415.9    |  0.1052   |
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\LYL\lib\site-packages\bayes_opt\target_space.py in probe(self, params)
#     190         try:
# --> 191             target = self._cache[_hashable(x)]
#     192         except KeyError:
#
# KeyError: (1.80643545572701, 3.5817647919328692, 603.5418928155533, 1.0092454820865775)
#
# ...

# %%
bo = ensemble_Bayesian.myBayesianoptimazation("ExtraTrees",X_train, X_test, y_train, y_test,random_seed = 1998,save_path = "./ensembleLearning_hk/ExtraTrees/",kFold = 10 )
bo.run()
# Out:
# |   iter    |  target   | min_sa... | n_esti... |
# -------------------------------------------------
# |  1        |  0.9149   |  2.676    |  175.3    |
# |  2        |  0.9044   |  2.158    |  28.31    |
# |  3        |  0.903    |  5.282    |  97.91    |
# |  4        |  0.9088   |  5.267    |  168.1    |
# |  5        |  0.8956   |  8.228    |  45.99    |
# |  6        |  0.8915   |  6.032    |  64.55    |
# |  7        |  0.9097   |  2.537    |  139.1    |
# |  8        |  0.9001   |  7.029    |  144.3    |
# |  9        |  0.9129   |  3.843    |  152.6    |
# |  10       |  0.9187   |  4.446    |  103.2    |
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\LYL\lib\site-packages\bayes_opt\target_space.py in probe(self, params)
#     190         try:
# --> 191             target = self._cache[_hashable(x)]
#     192         except KeyError:
#
# ...

# %%
bo = ensemble_Bayesian.myBayesianoptimazation("bagging",X_train, X_test, y_train, y_test,random_seed = 1998,save_path = "./ensembleLearning_hk/bagging/",kFold = 10 )
bo.run()
# Out:
# |   iter    |  target   | max_fe... | max_sa... | n_esti... |
# -------------------------------------------------------------
# |  1        |  0.8302   |  0.7825   |  0.9911   |  220.3    |
# |  2        |  0.7709   |  0.5736   |  0.557    |  187.4    |
# |  3        |  0.8386   |  0.988    |  0.9809   |  385.4    |
# |  4        |  0.8054   |  0.8084   |  0.5318   |  141.8    |
# |  5        |  0.8319   |  0.9031   |  0.9394   |  252.6    |
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\LYL\lib\site-packages\bayes_opt\target_space.py in probe(self, params)
#     190         try:
# --> 191             target = self._cache[_hashable(x)]
#     192         except KeyError:
#
# KeyError: (0.6274718971525215, 0.8748124004342666, 149.51896211595988)
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
bo = ensemble_Bayesian.myBayesianoptimazation("BLS",X_train, X_test, y_train, y_test,random_seed = 1998,save_path = "./ensembleLearning_hk/BLS/",kFold = 10 )
bo.run()
# Out:
# |   iter    |  target   |     C     | NumEnhan  |  NumFea   |  NumWin   |     S     |
# -------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\LYL\lib\site-packages\bayes_opt\target_space.py in probe(self, params)
#     190         try:
# --> 191             target = self._cache[_hashable(x)]
#     192         except KeyError:
#
# KeyError: (0.2035564755520719, 10.323320160434097, 37.53435627841815, 15.153348705123253, 0.9517568590191906)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-2fc677e4ceed> in <module>
# ...

# %%
bo = ensemble_Bayesian.myBayesianoptimazation("LogisticR",X_train, X_test, y_train, y_test,random_seed = 1998,save_path = "./ensembleLearning_hk/LogisticR/",kFold = 10 )
bo.run()
# Out:
# |   iter    |  target   |     C     |  penalty  |    tol    |
# -------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\LYL\lib\site-packages\bayes_opt\target_space.py in probe(self, params)
#     190         try:
# --> 191             target = self._cache[_hashable(x)]
#     192         except KeyError:
#
# KeyError: (1.046336768597499, 1.4985367963523193, 0.002025832108345494)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-335e8fc68085> in <module>
#       1 bo = ensemble_Bayesian.myBayesianoptimazation("LogisticR",X_train, X_test, y_train, y_test,random_seed = 1998,save_path = "./ensembleLearning_hk/model/",kFold = 10 )
# ----> 2 bo.run()
#
# ...

# %%
bo = ensemble_Bayesian.myBayesianoptimazation("GPR",X_train, X_test, y_train, y_test,random_seed = 1998,save_path = "./ensembleLearning_hk/GPR/",kFold = 10 )
bo.run()
# Out:
# |   iter    |  target   |   alpha   | normal... |
# -------------------------------------------------
# |  1        |  0.008356 |  6.665e-0 |  0.1912   |
# |  2        |  0.008356 |  4.977e-0 |  0.4885   |
# |  3        | -6.032    |  8.324e-0 |  1.567    |
# |  4        | -6.032    |  6.997e-0 |  1.456    |
# |  5        | -6.032    |  7.497e-0 |  1.395    |
# |  6        |  0.008356 |  3.761e-0 |  0.0221   |
# |  7        | -6.032    |  8.218e-0 |  1.071    |
# |  8        | -6.032    |  1.239e-0 |  1.937    |
# |  9        | -6.032    |  6.801e-0 |  1.744    |
# |  10       | -6.032    |  4.56e-06 |  1.598    |
# |  11       |  0.008356 |  3.638e-0 |  0.7316   |
# |  12       | -6.032    |  7.71e-06 |  1.852    |
# |  13       | -6.032    |  7.68e-06 |  1.031    |
# |  14       | -6.032    |  7.66e-06 |  1.911    |
# |  15       | -6.032    |  4.144e-0 |  1.236    |
# |  16       | -6.032    |  6.769e-0 |  1.663    |
# |  17       |  0.008356 |  9.022e-0 |  0.8417   |
# ...

# %%
bo = ensemble_Bayesian.myBayesianoptimazation("BayesianRidge",X_train, X_test, y_train, y_test,random_seed = 1998,save_path = "./ensembleLearning_hk/BayesianRidge/",kFold = 10 )
bo.run()
# Out:
# |   iter    |  target   |  alpha_1  |  alpha_2  | lambda_1  | lambda_2  |  n_iter   | normalize |    tol    |
# -------------------------------------------------------------------------------------------------------------
# |  1        |  0.6643   |  0.008521 |  0.003605 |  0.008392 |  0.009454 |  375.2    |  1.411    |  0.001207 |
# |  2        |  0.6643   |  0.005288 |  0.001293 |  0.004321 |  0.007863 |  613.2    |  1.504    |  0.001382 |
# |  3        |  0.7037   |  0.009232 |  0.008343 |  0.004728 |  0.007612 |  523.7    |  0.2982   |  0.007841 |
# |  4        |  0.6643   |  0.009697 |  0.002733 |  0.00799  |  0.005084 |  756.2    |  1.386    |  0.003597 |
# |  5        |  0.7037   |  0.004789 |  0.002032 |  0.005813 |  0.001241 |  197.8    |  0.8598   |  0.002717 |
# |  6        |  0.6643   |  0.008838 |  0.003137 |  0.001993 |  0.008823 |  624.7    |  1.164    |  0.005091 |
# ...

# %%
bo = ensemble_Bayesian.myBayesianoptimazation("PAR",X_train, X_test, y_train, y_test,random_seed = 1998,save_path = "./ensembleLearning_hk/PAR/",kFold = 10 )
bo.run()
# Out:
# |   iter    |  target   |     C     |    tol    |
# -------------------------------------------------
# |  1        | -0.03235  |  2.305    |  0.00631  |
# |  2        | -0.03235  |  0.936    |  0.001653 |
# |  3        | -0.03235  |  0.9578   |  0.004485 |
# |  4        | -0.03235  |  1.75     |  0.00643  |
# |  5        | -0.03235  |  1.603    |  0.003305 |
# |  6        | -0.03235  |  1.441    |  0.008387 |
# |  7        | -0.03235  |  1.062    |  0.006474 |
# |  8        | -0.03235  |  2.216    |  0.000665 |
# |  9        | -0.03235  |  0.9734   |  0.004756 |
# |  10       | -0.03235  |  1.62     |  0.007109 |
# |  11       | -0.03235  |  0.8824   |  0.005687 |
# |  12       | -0.03235  |  1.647    |  0.003114 |
# |  13       | -0.03235  |  2.272    |  0.009341 |
# |  14       | -0.03235  |  2.353    |  0.006898 |
# |  15       | -0.03235  |  1.51     |  0.007383 |
# |  16       | -0.03235  |  0.6546   |  0.007878 |
# |  17       | -0.03235  |  1.571    |  0.006429 |
# ...

# %%
bo = ensemble_Bayesian.myBayesianoptimazation("Lr_Sgd",X_train, X_test, y_train, y_test,random_seed = 1998,save_path = "./ensembleLearning_hk/Lr_Sgd/",kFold = 10 )
bo.run()
# Out:
# |   iter    |  target   |   alpha   |   eta0    | l1_ratio  | learni... |   loss    |  penalty  |  power_t  |    tol    |
# -------------------------------------------------------------------------------------------------------------------------
# |  1        | -3.421e+0 |  0.00859  |  0.007428 |  0.2263   |  0.9899   |  2.696    |  2.267    |  0.4072   |  0.008271 |
# |  2        |  0.3436   |  0.007826 |  0.008601 |  0.3542   |  3.345    |  1.002    |  1.603    |  0.1479   |  0.005529 |
# |  3        | -13.83    |  0.007274 |  0.007953 |  0.3364   |  0.7135   |  1.973    |  1.964    |  0.127    |  0.002074 |
# |  4        | -3.207    |  0.005026 |  0.0075   |  0.2987   |  2.448    |  2.625    |  2.265    |  0.3779   |  0.006757 |
# |  5        | -6.233e+2 |  0.008191 |  0.004394 |  0.1787   |  0.8781   |  3.398    |  0.4488   |  0.3488   |  0.008839 |
# |  6        | -9.655e+2 |  0.008534 |  0.006862 |  0.09699  |  1.934    |  3.664    |  1.116    |  0.3      |  0.006638 |
# ...

# %%
bo = ensemble_Bayesian.myBayesianoptimazation("DecisionTree",X_train, X_test, y_train, y_test,random_seed = 1998,save_path = "./ensembleLearning_hk/DecisionTree/",kFold = 10 )
bo.run()
# Out:
# |   iter    |  target   | min_sa... | min_sa... | splitter  |
# -------------------------------------------------------------
# 0.3020258037999475 2.4513845291989207 4.228520842714683
# |  1        |  0.738    |  4.229    |  2.451    |  0.302    |
# 0.49698466059469176 2.2071035087372044 1.5464552340060687
# |  2        |  0.7093   |  1.546    |  2.207    |  0.497    |
# 1.3784833676080972 5.563757559566648 1.778983033703081
# |  3        |  0.5712   |  1.779    |  5.564    |  1.378    |
# 1.6432883523724002 3.902791294221795 4.336983782890781
# |  4        |  0.6583   |  4.337    |  3.903    |  1.643    |
# 1.9821293569650882 4.747367341573886 4.469564724156694
# |  5        |  0.6583   |  4.47     |  4.747    |  1.982    |
# 1.2439836805178066 3.2305408840017265 3.1300434880268395
# |  6        |  0.5802   |  3.13     |  3.231    |  1.244    |
# 1.3289486395388235 5.7451747658605665 2.561749260200103
# |  7        |  0.6678   |  2.562    |  5.745    |  1.329    |
# ...

# %%
bo = ensemble_Bayesian.myBayesianoptimazation("LinearSvr",X_train, X_test, y_train, y_test,random_seed = 1998,save_path = "./ensembleLearning_hk/LinearSvr/",kFold = 10 )
bo.run()
# Out:
# |   iter    |  target   |     C     |   loss    |    tol    |
# -------------------------------------------------------------
# D:\Anaconda3\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# D:\Anaconda3\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# D:\Anaconda3\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# D:\Anaconda3\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# ...

# %%
bo = ensemble_Bayesian.myBayesianoptimazation("KNN",X_train, X_test, y_train, y_test,random_seed = 1998,save_path = "./ensembleLearning_hk/KNN/",kFold = 10 )
bo.run()
# Out:
# |   iter    |  target   |     P     | leaf_size | n_neig... |  weights  |
# -------------------------------------------------------------------------
# |  1        |  0.4153   |  0.9839   |  43.83    |  5.342    |  0.2918   |
# |  2        |  0.399    |  0.4242   |  43.88    |  3.772    |  0.4092   |
# |  3        |  0.4153   |  0.1235   |  15.26    |  5.093    |  0.2845   |
# |  4        |  0.4202   |  0.2233   |  20.7     |  3.466    |  1.463    |
# |  5        |  0.4843   |  0.1878   |  35.49    |  9.079    |  1.621    |
# |  6        |  0.4493   |  0.9412   |  26.29    |  5.527    |  1.711    |
# |  7        |  0.4283   |  0.4104   |  43.18    |  8.841    |  0.8919   |
# |  8        |  0.4843   |  0.1707   |  18.69    |  9.085    |  1.432    |
# |  9        |  0.4202   |  0.6838   |  20.75    |  3.304    |  1.104    |
# |  10       |  0.4202   |  0.5837   |  36.88    |  3.826    |  1.964    |
# |  11       |  0.4979   |  0.5786   |  25.07    |  4.073    |  1.131    |
# ...
